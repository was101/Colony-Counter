# %% [markdown]
# <a href="https://colab.research.google.com/github/was101/Colony-Counter/blob/main/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D/%ED%83%80%EC%9D%B4%ED%83%80%EB%8B%89_%EB%8D%B0%EC%9D%B4%ED%84%B0_%ED%9A%8C%EA%B7%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
train = pd.read_csv('/content/train.csv')
test = pd.read_csv('/content/test.csv')

# %%
f, ax = plt.subplots(1,2,figsize=(18,8))
train['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%', ax = ax[0], shadow=True)

ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot(x=train['Survived'],ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
pd.crosstab(train.Pclass, train.Survived, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_e3f00_row0_col0, #T_e3f00_row1_col1, #T_e3f00_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_e3f00_row0_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_e3f00_row0_col2 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_e3f00_row1_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_e3f00_row2_col0 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_e3f00_row2_col1 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_e3f00_row2_col2 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_e3f00_row3_col0, #T_e3f00_row3_col1, #T_e3f00_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e3f00" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_e3f00_level0_col0" class="col_heading level0 col0" >0</th>
# ...

# %%
f, ax = plt.subplots(1,2,figsize=(18,8))
train['Pclass'].value_counts().plot.bar(color=['#cd7F32','#FFDF00','#D3D3D3'], ax=ax[0])
ax[0].set_title('Number of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot(x='Pclass',hue='Survived',data=train,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %%
pd.crosstab([train.Sex, train.Survived],train.Pclass, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_c702d_row0_col0, #T_c702d_row0_col1, #T_c702d_row0_col3, #T_c702d_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_c702d_row0_col2, #T_c702d_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_c702d_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_c702d_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_c702d_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_c702d_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_c702d_row2_col1, #T_c702d_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_c702d_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_c702d_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_c702d_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_c702d_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# ...

# %%
sns.pointplot(x='Pclass',y='Survived',hue='Sex',data=train)
plt.show()

# %%
print('Oldest Passenger was of:', train['Age'].max(),'Years')
print('Youngest Passenger was of:', train['Age'].min(),'Years')
print('Average Age on the ship:', train['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
f, ax = plt.subplots(1,2,figsize=(18,8))
sns.violinplot(x='Pclass',y='Age',hue='Survived',data=train,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot(x='Sex',y='Age',hue='Survived',data=train,split=True,ax=ax[1])
ax[0].set_title('Sex and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
plt.show()

# %%
s2 = pd.Series(['a_b_c', 'c_d_e', np.nan, 'f_g_h'], dtype='string')

# %%
s2.str.split('_')
# Out:
# 0    [a, b, c]
# 1    [c, d, e]
# 2         <NA>
# 3    [f, g, h]
# dtype: object

# %%
s2.str.split('_').str.get(1)
# Out:
# 0       b
# 1       d
# 2    <NA>
# 3       g
# dtype: object

# %%
s2.str.split('_').str[1]
# Out:
# 0       b
# 1       d
# 2    <NA>
# 3       g
# dtype: object

# %%
s2.str.split('_',expand = True)
# Out:
#       0     1     2
# 0     a     b     c
# 1     c     d     e
# 2  <NA>  <NA>  <NA>
# 3     f     g     h

# %%
s2.str.split('_', expand = False)
# Out:
# 0    [a, b, c]
# 1    [c, d, e]
# 2         <NA>
# 3    [f, g, h]
# dtype: object

# %%
s2.str.split('_',expand = True, n=1)
# Out:
#       0     1
# 0     a   b_c
# 1     c   d_e
# 2  <NA>  <NA>
# 3     f   g_h

# %%
s2.str.split('_',expand = True, n=2)
# Out:
#       0     1     2
# 0     a     b     c
# 1     c     d     e
# 2  <NA>  <NA>  <NA>
# 3     f     g     h

# %%
s3 = pd.Series(['A','B','C','AaBa','Baca',np.nan,'CABA','dog','cat'], dtype='string')
s3
# Out:
# 0       A
# 1       B
# 2       C
# 3    AaBa
# 4    Baca
# 5    <NA>
# 6    CABA
# 7     dog
# 8     cat
# dtype: string

# %%
s3.str.replace('^.a|dog','XX-XX',case=False)
# Out:
# <ipython-input-91-79daf3abf2eb>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   s3.str.replace('^.a|dog','XX-XX',case=False)
# 0          A
# 1          B
# 2          C
# 3    XX-XXBa
# 4    XX-XXca
# 5       <NA>
# 6    XX-XXBA
# 7      XX-XX
# 8     XX-XXt
# dtype: string

# %%
s3.str.replace('^.a|dog','XX-XX',case=True)
# Out:
# <ipython-input-92-7a7d8de12770>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   s3.str.replace('^.a|dog','XX-XX',case=True)
# 0          A
# 1          B
# 2          C
# 3    XX-XXBa
# 4    XX-XXca
# 5       <NA>
# 6       CABA
# 7      XX-XX
# 8     XX-XXt
# dtype: string

# %%
s3.str.replace('^a|dog','XX-XX',case=False)
# Out:
# <ipython-input-89-b0c65ec601bf>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   s3.str.replace('^a|dog','XX-XX',case=False)
# 0       XX-XX
# 1           B
# 2           C
# 3    XX-XXaBa
# 4        Baca
# 5        <NA>
# 6        CABA
# 7       XX-XX
# 8         cat
# dtype: string

# %%
dollars = pd.Series(['12','-$10','$10,000'], dtype='string')
dollars
# Out:
# 0         12
# 1       -$10
# 2    $10,000
# dtype: string

# %%
dollars.str.replace('$','')
# Out:
# <ipython-input-94-a37891b046c2>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dollars.str.replace('$','')
# 0        12
# 1       -10
# 2    10,000
# dtype: string

# %%
dollars.str.replace('-$','')
# Out:
# <ipython-input-95-f7d07c483588>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   dollars.str.replace('-$','')
# 0         12
# 1       -$10
# 2    $10,000
# dtype: string

# %%
dollars.str.replace(r'-\$','')
# Out:
# <ipython-input-96-d70fda9764d3>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   dollars.str.replace(r'-\$','')
# 0         12
# 1         10
# 2    $10,000
# dtype: string

# %%
dollars.str.replace(r'-\$','',regex=True)
# Out:
# 0         12
# 1         10
# 2    $10,000
# dtype: string

# %%
train['Famillysize'] = train['SibSp'] + train['Parch'] + 1
test['Famillysize'] = test['SibSp'] + test['Parch'] + 1

# %%
train['Famillysize']
# Out:
# 0      2
# 1      2
# 2      1
# 3      2
# 4      1
#       ..
# 886    1
# 887    1
# 888    4
# 889    1
# 890    1
# Name: Famillysize, Length: 891, dtype: int64

# %%
test['Famillysize']
# Out:
# 0      1
# 1      2
# 2      1
# 3      1
# 4      3
#       ..
# 413    1
# 414    1
# 415    1
# 416    1
# 417    3
# Name: Famillysize, Length: 418, dtype: int64

# %%
facet = sns.FacetGrid(train, hue='Survived', aspect=4)
facet.map(sns.kdeplot, 'Famillysize', shade=True)
facet.set(xlim=(0, train['Famillysize'].max()))
facet.add_legend()

plt.show()

# %%
X_train = train.drop(["Survived", 'PassengerId'], axis=1)
Y_train = train['Survived']
X_test = test.drop('PassengerId', axis=1).copy()

# %%
X_train.isna().sum()
# Out:
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Famillysize      0
# dtype: int64

# %%
X_test.isna().sum()
# Out:
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Famillysize      0
# dtype: int64

# %%
X_test['Fare'].fillna(0,inplace=True)

# %%
X_train.drop('Name',axis=1,inplace=True)
X_test.drop('Name',axis=1,inplace=True)

# %%
X_train.drop('Ticket',axis=1,inplace=True)
X_test.drop('Ticket',axis=1,inplace=True)

# %%
X_train.drop('Cabin',axis=1,inplace=True)
X_test.drop('Cabin',axis=1,inplace=True)

# %%
X_train.drop('Embarked',axis=1,inplace=True)
X_test.drop('Embarked',axis=1,inplace=True)

# %%
X_train.drop('Age',axis=1,inplace=True)
X_test.drop('Age',axis=1,inplace=True)

# %%
X_train.drop('Sex',axis=1,inplace=True)
X_test.drop('Sex',axis=1,inplace=True)

# %%
X_train
# Out:
#      Pclass     Sex  SibSp  Parch     Fare  Famillysize
# 0         3    male      1      0   7.2500            2
# 1         1  female      1      0  71.2833            2
# 2         3  female      0      0   7.9250            1
# 3         1  female      1      0  53.1000            2
# 4         3    male      0      0   8.0500            1
# ..      ...     ...    ...    ...      ...          ...
# 886       2    male      0      0  13.0000            1
# 887       1  female      0      0  30.0000            1
# 888       3  female      1      2  23.4500            4
# 889       1    male      0      0  30.0000            1
# 890       3    male      0      0   7.7500            1
#
# [891 rows x 6 columns]

# %%
from sklearn.linear_model import LinearRegression

lig_reg = LinearRegression()
lig_reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = lig_reg.predict(X_test)

# %%
df1 = pd.DataFrame(Y_pred)
df1
# Out:
#             0
# 0    0.240864
# 1    0.211323
# 2    0.408340
# 3    0.241605
# 4    0.272972
# ..        ...
# 413  0.241060
# 414  0.662341
# 415  0.240349
# 416  0.241060
# 417  0.281922
#
# [418 rows x 1 columns]
